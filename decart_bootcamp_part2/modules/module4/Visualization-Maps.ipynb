# %% [markdown]
# ## Visualizing Spatial Data with Pandas and Bokeh

# %% [markdown]
# [bokeh](http://bokeh.pydata.org/en/latest/) is a relatively new JavaScript visualization language for Python that is modeled after D3 but is intended to be able to handle millions of data points.
#
# >Bokeh is a Python interactive visualization library that targets modern web browsers for presentation. Its goal is to provide elegant, concise construction of novel graphics in the style of D3.js, and to extend this capability with high-performance interactivity over very large or streaming datasets. Bokeh can help anyone who would like to quickly and easily create interactive plots, dashboards, and data applications. ([Bokeh Website](http://bokeh.pydata.org/en/latest/))
#
# The advantage of Bokeh over matplotlib is that the visualizations can be interactive (via the JavaScript).
#
# From the U.K. accident data, we can plot the location of accidents for which latitude and longitude values are provided.

# %%
import os
import sqlite3 as sqlite
DATADIR = os.path.join(os.path.expanduser("~"),"DATA",
                       "Misc")
print(os.path.exists(DATADIR))
import pandas as pd
import numpy as np
# Out:
# True

# %%
from bokeh.io import output_notebook

# %% [markdown]
# ### This enables drawing directly in the notebook

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a5b0f7db-ed7e-49fd-b6ee-5497a928b85c">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Read in the data

# %%
data = pd.read_csv(os.path.join(DATADIR,
                         "Accidents7904.csv"),
                   usecols = ['Longitude',"Latitude","Date"]).dropna()
data.head()
# Out:
#          Longitude   Latitude        Date
# 4883216  -0.271752  51.715661  25/12/1999
# 4883217  -0.239977  51.695136  17/12/1999
# 4883218  -0.270037  51.715096  15/12/1999
# 4883219  -0.263233  51.711309  02/12/1999
# 4883220  -0.227225  51.688200  04/12/1999

# %%
data.dtypes
# Out:
# Longitude    float64
# Latitude     float64
# Date          object
# dtype: object

# %% [markdown]
# ####  We can use the [``sample``](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sample.html) method to get a subset of DataFrame

# %%
subdata = data.sample(200)
mean_long = np.mean(subdata['Longitude'])
mean_lat  = np.mean(subdata['Latitude'])

# %%
from bokeh.io import output_file, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, DataRange1d, 
    PanTool, WheelZoomTool, BoxSelectTool, HoverTool
)

hover = HoverTool()
map_options = GMapOptions(lat=mean_lat, 
                          lng=mean_long, 
                          map_type="roadmap", zoom=6)

plot = GMapPlot(
    x_range=DataRange1d(), 
    y_range=DataRange1d(), 
    map_options=map_options
)
plot.title.text = "U.K. Road Accidents"

source = ColumnDataSource(
    data=dict(
        lat=subdata['Latitude'],
        lon=subdata['Longitude'],
    )
)


hover.tooltips.append(('index','$index'))
circle = Circle(x="lon", y="lat", size=2, 
                fill_color="blue", fill_alpha=0.8, 
                line_color=None)
plot.add_glyph(source, circle)

plot.add_tools(PanTool(),WheelZoomTool(), BoxSelectTool(), hover)
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="94b7a8eb-6e93-4f83-8813-b8db9cd2ea2f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("94b7a8eb-6e93-4f83-8813-b8db9cd2ea2f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("94b7a8eb-6e93-4f83-8813-b8db9cd2ea2f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '94b7a8eb-6e93-4f83-8813-b8db9cd2ea2f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9d10ad57-2050-41ae-b877-baef0ec43963":{"roots":{"references":[{"attributes":{"callback":null},"id":"a28a22f0-674b-4c84-b5d2-dd0d61b70144","type":"DataRange1d"},{"attributes":{},"id":"061b0141-ff9f-415a-8198-6efc0d011904","type":"ToolEvents"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"be51756d-a98f-42f8-ac52-24dcbd93a995","type":"PanTool"},{"id":"3305f30e-c0b1-4e45-b1d1-318e5736c45e","type":"WheelZoomTool"},{"id":"0897765b-b93b-48da-9ba3-bc52fcadb1d5","type":"BoxSelectTool"},{"id":"662bb7a3-ed45-4754-862c-113f95a65298","type":"HoverTool"}]},"id":"4f2609b6-fba4-4d6f-853c-501ce4a1859d","type":"Toolbar"},{"attributes":{"plot":{"id":"1c760c4f-08b9-4875-b230-4cf8b4dc18aa","type":"GMapPlot"}},"id":"3305f30e-c0b1-4e45-b1d1-318e5736c45e","type":"WheelZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7136263e-4802-4d0a-bd08-a5e78bdd4f05","type":"BoxAnnotation"},{"attributes":{"map_options":{"id":"0995caee-c909-4c46-bcdc-2bef00726787","type":"GMapOptions"},"renderers":[{"id":"02dd9d59-7632-4da9-bf74-c77e85c6bcdd","type":"GlyphRenderer"},{"id":"7136263e-4802-4d0a-bd08-a5e78bdd4f05","type":"BoxAnnotation"}],"title":{"id":"f0a7ed9e-cf68-4ec6-b86f-479dd435d8d7","type":"Title"},"tool_events":{"id":"061b0141-ff9f-415a-8198-6efc0d011904","type":"ToolEvents"},"toolbar":{"id":"4f2609b6-fba4-4d6f-853c-501ce4a1859d","type":"Toolbar"},"x_range":{"id":"b09892c1-1dcd-4704-8923-ed12fdfea695","type":"DataRange1d"},"y_range":{"id":"a28a22f0-674b-4c84-b5d2-dd0d61b70144","type":"DataRange1d"}},"id":"1c760c4f-08b9-4875-b230-4cf8b4dc18aa","type":"GMapPlot"},{"attributes":{"data_source":{"id":"ca1d2a97-8f9a-4500-8ddb-f93928ee446c","type":"ColumnDataSource"},"glyph":{"id":"07e17cd8-c815-48a0-9bb4-0b084ca178f8","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"02dd9d59-7632-4da9-bf74-c77e85c6bcdd","type":"GlyphRenderer"},{"attributes":{"callback":null,"overlay":{"id":"7136263e-4802-4d0a-bd08-a5e78bdd4f05","type":"BoxAnnotation"},"plot":{"id":"1c760c4f-08b9-4875-b230-4cf8b4dc18aa","type":"GMapPlot"}},"id":"0897765b-b93b-48da-9ba3-bc52fcadb1d5","type":"BoxSelectTool"},{"attributes":{"callback":null},"id":"b09892c1-1dcd-4704-8923-ed12fdfea695","type":"DataRange1d"},{"attributes":{"plot":null,"text":"U.K. Road Accidents"},"id":"f0a7ed9e-cf68-4ec6-b86f-479dd435d8d7","type":"Title"},{"attributes":{"callback":null,"column_names":["lat","lon"],"data":{"lat":{"__ndarray__":"...","dtype":"float64","shape":[200]},"lon":{"__ndarray__":"...","dtype":"float64","shape":[200]}}},"id":"ca1d2a97-8f9a-4500-8ddb-f93928ee446c","type":"ColumnDataSource"},{"attributes":{"callback":null,"plot":{"id":"1c760c4f-08b9-4875-b230-4cf8b4dc18aa","type":"GMapPlot"}},"id":"662bb7a3-ed45-4754-862c-113f95a65298","type":"HoverTool"},{"attributes":{"fill_alpha":{"value":0.8},"fill_color":{"value":"blue"},"line_color":{"value":null},"size":{"units":"screen","value":2},"x":{"field":"lon"},"y":{"field":"lat"}},"id":"07e17cd8-c815-48a0-9bb4-0b084ca178f8","type":"Circle"},{"attributes":{"lat":52.49013942,"lng":-1.3511062349999998,"zoom":6},"id":"0995caee-c909-4c46-bcdc-2bef00726787","type":"GMapOptions"},{"attributes":{"plot":{"id":"1c760c4f-08b9-4875-b230-4cf8b4dc18aa","type":"GMapPlot"}},"id":"be51756d-a98f-42f8-ac52-24dcbd93a995","type":"PanTool"}],"root_ids":["1c760c4f-08b9-4875-b230-4cf8b4dc18aa"]},"title":"Bokeh Application","version":"0.12.5"}};
#             var render_items = [{"docid":"9d10ad57-2050-41ae-b877-baef0ec43963","elementid":"94b7a8eb-6e93-4f83-8813-b8db9cd2ea2f","modelid":"1c760c4f-08b9-4875-b230-4cf8b4dc18aa"}];
#
#             Bokeh.embed.embed_items(docs_json, render_items);
#           };
#           if (document.readyState != "loading") fn();
#           else document.addEventListener("DOMContentLoaded", fn);
#         })();
#       },
#       function(Bokeh) {
#       }
#     ];
#
#     function run_inline_js() {
#
#       if ((window.Bokeh !== undefined) || (force === true)) {
#         for (var i = 0; i < inline_js.length; i++) {
#           inline_js[i](window.Bokeh);
#         }if (force === true) {
#           display_loaded();
#         }} else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(run_inline_js, 100);
#       } else if (!window._bokeh_failed_load) {
